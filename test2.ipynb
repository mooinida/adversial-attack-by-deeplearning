# %%
import numpy as np

# %%
a=np.array([[1,2]])
b=np.array([[3,4],[5,6]])

print(np.dot(b,a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-4d51ca3d5c8c> in <cell line: 4>()
#       2 b=np.array([[3,4],[5,6]])
#       3
# ----> 4 print(np.dot(b,a))
#
# ValueError: shapes (2,2) and (1,2) not aligned: 2 (dim 1) != 1 (dim 0)

# %%
print(a.shape())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-bbecd3d6f9bc> in <cell line: 1>()
# ----> 1 print(a.shape())
#
# TypeError: 'tuple' object is not callable

# %%
print(1+4)
# Out:
# 5

# %%
a=np.array([1,1])
b=np.array([[0,-1],[1,0]])
print(np.dot(a,b))
# Out:
# [ 1 -1]

# %%
ㄷ
